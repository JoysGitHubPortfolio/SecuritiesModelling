# %%
import yfinance as yf
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
# Fetch the ticker data for AstraZeneca
azn_lond = yf.Ticker('AZN.L')
azn_lond_hist = azn_lond.history(period="5y")

# %%
azn_lond_hist = azn_lond_hist.reset_index()
azn_lond_hist['Date'] = pd.to_datetime(azn_lond_hist['Date']).dt.date
azn_lond_hist
# Out:
#             Date          Open          High           Low         Close  \
# 0     2019-08-09   6383.657145   6605.127349   6357.966602   6512.109863
# 1     2019-08-12   6509.452202   6551.974481   6466.283248   6493.506348
# 2     2019-08-13   6472.244525   6546.658505   6464.271598   6504.136230
# 3     2019-08-14   6548.430619   6622.091518   6412.890862   6439.467285
# 4     2019-08-15   6429.722140   6477.506493   6348.221115   6404.917480
# ...          ...           ...           ...           ...           ...
# 1258  2024-08-05  12493.133471  12514.998939  12185.029145  12381.818359
# 1259  2024-08-06  12379.830499  12395.732658  12123.408191  12332.124023
# 1260  2024-08-07  12353.989339  12626.313803  12336.099411  12612.399414
# 1261  2024-08-08  12626.000000  12666.000000  12432.000000  12628.000000
# 1262  2024-08-09  12666.000000  12724.000000  12598.000000  12700.000000
#
#        Volume  Dividends  Stock Splits
# 0     2708310        0.0           0.0
# ...

# %%
azn_lond_hist.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   1263.000000   1263.000000   1263.000000   1263.000000  1.263000e+03
# mean    8902.557241   8999.885933   8808.072271   8904.317006  2.400218e+06
# std     1813.800062   1821.628114   1806.039592   1815.989042  2.046481e+06
# min     5526.345586   5706.189049   5305.834005   5622.141602  6.793300e+04
# 25%     7396.936442   7481.146785   7329.351254   7397.978271  1.552762e+06
# 50%     8396.425870   8540.741996   8318.220480   8423.579102  2.061222e+06
# 75%    10439.545431  10538.220237  10336.153570  10438.554199  2.800150e+06
# max    12666.000000  12724.000000  12598.000000  12700.000000  6.029139e+07
#
#          Dividends  Stock Splits
# count  1263.000000        1263.0
# mean      0.877356           0.0
# std      10.432357           0.0
# min       0.000000           0.0
# 25%       0.000000           0.0
# 50%       0.000000           0.0
# 75%       0.000000           0.0
# ...

# %%
date = azn_lond_hist['Date']
close = azn_lond_hist['Close']

# Plot the data
plt.figure()
plt.plot(date, close, marker='.', linestyle='-')
plt.title('AstraZeneca (AZN) Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (GBX)')
plt.xticks(rotation=45)  # Rotate date labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of tick-labels
plt.show()
